# %%
import numpy as np

# %%
def sigmoid(x):
    """Return the sigmoid activation of x."""
    return 1 / (1 + np.exp(-x))

# %%
def forward_hidden(X, Wzh):
    """
    Compute hidden layer activations.

    Parameters:
        X   : (5 x N) input matrix
        Wzh : (6 x 3) weight matrix for hidden layer (includes bias weights)

    Returns:
        Z_hidden : (3 x N) activations after sigmoid
    """
    # TODO: 1) Add bias term to X
    # TODO: 2) Compute pre-activation
    # TODO: 3) Apply sigmoid
    pass

# %%
def batch_norm_hidden(Z, gamma, beta, eps=1e-8, batch_size=3):
    """
    Apply batch normalization across mini-batches.

    Parameters:
        Z         : (3 x N) hidden activations
        gamma     : scaling parameter
        beta      : shifting parameter
        eps       : small constant for numerical stability
        batch_size: number of samples per mini-batch

    Returns:
        Z_bn : (3 x N) batch normalized activations
    """
    # TODO: Implement batch norm 

    pass

# %%
def layer_norm_hidden(Z, gamma, beta, eps=1e-8):
    """
    Apply layer normalization across hidden units for each sample.

    Parameters:
        Z     : (3 x N) hidden activations
        gamma : scaling parameter
        beta  : shifting parameter
        eps   : small constant for numerical stability

    Returns:
        Z_ln : (3 x N) layer normalized activations
    """
    # TODO: Implement layer norm
    pass

# %%
def main():
    # Load provided matrices here
    Wzh = np.array([...])   # TODO: paste values from assignment
    Wf = np.array([...])    # TODO: paste values from assignment

    X = np.array([...])     # TODO: paste input data

    gamma = 2
    beta = 10

    Z_hidden = forward_hidden(X, Wzh)

    Z_bn = batch_norm_hidden(Z_hidden, gamma, beta)
    print("Batch Norm Result:\n", Z_bn)

    Z_ln = layer_norm_hidden(Z_hidden, gamma, beta)
    print("Layer Norm Result:\n", Z_ln)


if __name__ == "__main__":
    main()

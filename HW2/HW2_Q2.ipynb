# %%
import numpy as np

# %%
def sigmoid(v):
    """
    Sigmoid activation function.

    Input:
        v : net input (scalar or numpy array)

    Output:
        y : sigmoid(v)
    """
    # TODO (students): implement sigmoid activation
    pass

# %%
def load_data(pred_file, resp_file):
    """
    Load predictor matrix X and response vector d from files.

    Inputs:
        pred_file : file containing predictor matrix (rows = samples)
        resp_file : file containing response vector

    Outputs:
        X : input matrix (N x D)
        d : desired output vector (N,)
    """
    # TODO (students): load data from files
    pass

# %%
def predict(X, w):
    """
    Compute the output using a sigmoid activation.

    Notes:
        - Bias must be included in the weight vector.
        - Use augmented inputs: x_aug = [1, x1, ..., xD].

    Inputs:
        X : input matrix (N x D)
        w : weight vector (D+1,)

    Outputs:
        y : predicted output vector (N,)
    """
    # TODO (students): implement forward pass with sigmoid
    pass

# %%
def gradient_descent(X, d, eta, num_iters):
    """
    Estimate weights using gradient descent and sigmoid activation.

    Inputs:
        X         : training input matrix (N x D)
        d         : training labels (N,)
        eta       : learning rate
        num_iters : number of gradient descent iterations

    Outputs:
        w : learned weight vector (D+1,)
    """
    N, D = X.shape

    # Initialize weights (including bias)
    w = np.zeros(D + 1)

    # TODO (students): implement gradient descent update loop

    return w

# %%
def total_squared_error(y_pred, y_true):
    """
    Compute Total Squared Error (TSE).

    Inputs:
        y_pred : predicted outputs
        y_true : true labels

    Output:
        tse : total squared error
    """
    # TODO (students): implement TSE computation
    pass

# %%
def main_q2(pred_file, resp_file):
    # Load data
    X, d = load_data(pred_file, resp_file)

    # TODO (students):
    #   - Split the data into training and testing sets
    #   - Use the first half of the samples for training
    #   - Use the second half of the samples for testing

    # Hyperparameters (may be adjusted)
    eta = 0.01
    num_iters = 1000

    # TODO (students):
    #   - Train using gradient descent on the training set
    #   - Predict outputs on both training and testing sets
    #   - Compute and report the Total Squared Error (TSE)

# %%
main_q2("pred1.dat", "resp1.dat")
main_q2("pred2.dat", "resp2.dat")
